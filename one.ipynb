# %%
import numpy
import scipy
import pandas
import sklearn
import xgboost
import lightgbm

print(f"NumPy version: {numpy.__version__}")
print(f"SciPy version: {scipy.__version__}")
print(f"Pandas version: {pandas.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
print(f"XGBoost version: {xgboost.__version__}")
print(f"LightGBM version: {lightgbm.__version__}")
# Out:
# NumPy version: 1.26.4
# SciPy version: 1.15.0
# Pandas version: 2.2.3
# Scikit-learn version: 1.6.1
# XGBoost version: 2.1.3
# LightGBM version: 4.5.0

# %%
# !conda install xgboost -y
# Out:
# Vim configuration file: "$VIM/vimrc"
# User vimrc file: "$HOME/.vimrc"
# "~/.vim/vimrc"
# "~/.config/vim/vimrc"
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/marvinprakash/miniforge3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0          12 KB  conda-forge
#     libxgboost-2.1.4           |   cpu_hf17a1b1_0         1.3 MB  conda-forge
#     py-xgboost-2.1.4           | cpu_pyh43b6f25_0         132 KB  conda-forge
#     scipy-1.15.2               |  py312h99a188d_0        13.7 MB  conda-forge
#     xgboost-2.1.4              | cpu_pyhc1a9e11_0          15 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/osx-arm64::_py-xgboost-mutex-2.0-cpu_0
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_1
#   libxgboost         conda-forge/osx-arm64::libxgboost-2.1.4-cpu_hf17a1b1_0
#   py-xgboost         conda-forge/noarch::py-xgboost-2.1.4-cpu_pyh43b6f25_0
#   scikit-learn       conda-forge/osx-arm64::scikit-learn-1.6.1-py312h39203ce_0
#   scipy              conda-forge/osx-arm64::scipy-1.15.2-py312h99a188d_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.5.0-pyhc1e730c_0
#   xgboost            conda-forge/noarch::xgboost-2.1.4-cpu_pyhc1a9e11_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2024.12.14-hf0a4a13_0 --> 2025.1.31-hf0a4a13_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.1.31-pyhd8ed1ab_0
#   openssl                                  3.4.0-h81ee809_1 --> 3.4.1-h81ee809_0
#
#
#
# Downloading and Extracting Packages:
# scipy-1.15.2         | 13.7 MB   |                                       |   0%
# libxgboost-2.1.4     | 1.3 MB    |                                       |   0%
#
# py-xgboost-2.1.4     | 132 KB    |                                       |   0%
#
#
# xgboost-2.1.4        | 15 KB     |                                       |   0%
#
#
#
# scipy-1.15.2         | 13.7 MB   | 4                                     |   1%
#
#
# xgboost-2.1.4        | 15 KB     | ##################################### | 100%
#
#
# xgboost-2.1.4        | 15 KB     | ##################################### | 100%
#
#
# xgboost-2.1.4        | 15 KB     | ##################################### | 100%
# libxgboost-2.1.4     | 1.3 MB    | 4                                     |   1%
#
# py-xgboost-2.1.4     | 132 KB    | ###################################7  |  97%
#
# py-xgboost-2.1.4     | 132 KB    | ##################################### | 100%
#
# py-xgboost-2.1.4     | 132 KB    | ##################################### | 100%
# scipy-1.15.2         | 13.7 MB   | #9                                    |   5%
#
#
#
# _py-xgboost-mutex-2. | 12 KB     | ##################################### | 100%
#
#
#
# _py-xgboost-mutex-2. | 12 KB     | ##################################### | 100%
# scipy-1.15.2         | 13.7 MB   | ####                                  |  11%
#
#
#
# scipy-1.15.2         | 13.7 MB   | #####6                                |  15%
# libxgboost-2.1.4     | 1.3 MB    | ##################################1   |  92%
# libxgboost-2.1.4     | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
